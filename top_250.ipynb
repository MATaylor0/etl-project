# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import requests as req
from config import api_key
from pprint import pprint
import requests
import json

# %%
#Create list of top 250 IMBD movies to loop through 
table_MN = pd.read_html('https://www.imdb.com/chart/top/?ref_=nv_mv_250')
top_250=table_MN[0]["Rank & Title"].str[4:-6]
top_250=list(top_250)

# %%
#Create base
base_url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key

#Set up lists to hold response data
Title=[]
Year=[]
Rated=[]
Released=[]
Runtime=[]
Genre=[]
Director=[]
Writer=[]
Actors=[]
Plot=[]
Language=[]
Country=[]
Poster=[]
Metascore=[]
imdbID=[]
imdbRating=[]
imdbVotes=[]
Type=[]
DVD=[]
BoxOffice=[]
Production=[]
Website=[]

# %%
#Loop through movies and add info to lists 
for movie in top_250:
    target_url = base_url + movie + api_key
    response = requests.get(target_url).json()
    
    Title.append(response.get('Title'))
    Year.append(response.get('Year'))
    Rated.append(response.get('Rated'))
    Released.append(response.get('Released'))
    Runtime.append(response.get('Runtime'))
    Genre.append(response.get('Genre'))
    Director.append(response.get('Director'))
    Writer.append(response.get('Writer'))
    Actors.append(response.get('Actors'))
    Plot.append(response.get('Plot'))
    Language.append(response.get('Language'))
    Country.append(response.get('Country'))
    Poster.append(response.get('Poster'))
    Metascore.append(response.get('Metascore'))
    imdbID.append(response.get('imdbID'))
    imdbRating.append(response.get('imdbRating'))
    imdbVotes.append(response.get('imdbVotes'))
    Type.append(response.get('Type'))
    DVD.append(response.get('DVD'))
    BoxOffice.append(response.get('BoxOffice'))
    Production.append(response.get('Production'))
    Website.append(response.get('Website'))

# %%
#Create dataframe to hold data
top_250_df = pd.DataFrame({
    "Title":Title,
    "Year":Year,
    "Rated":Rated,
    "Released":Released,
    "Runtime":Runtime,
    "Genre":Genre,
    "Director":Director,
    "Writer":Writer,
    "Actors":Actors,
    "Plot":Plot,
    "Language":Language,
    "Country":Country,
    "Poster":Poster,
    "Metascore":Metascore,
    "imdbID":imdbID,
    "imdbRating":imdbRating,
    "imdbVotes":imdbVotes,
    "Type":Type,
    "DVD":DVD,
    "BoxOffice":BoxOffice,
    "Production":Production,
    "Website":Website
})

# %%
#Check for null value rows
top_250_df[top_250_df.isnull().any(axis=1)]

#Drop rows
top_250_df.dropna(how='all')
# Out:
#                         Title  Year      Rated     Released  Runtime  \
# 0    The Shawshank Redemption  1994          R  14 Oct 1994  142 min
# 1               The Godfather  1972          R  24 Mar 1972  175 min
# 2      The Godfather: Part II  1974          R  18 Dec 1974  202 min
# 3             The Dark Knight  2008      PG-13  18 Jul 2008  152 min
# 4                12 Angry Men  1957   Approved  10 Apr 1957   96 min
# ..                        ...   ...        ...          ...      ...
# 243                  The Help  2011      PG-13  10 Aug 2011  146 min
# 244                The Circus  1928     Passed  29 Jan 1928   72 min
# 246            The Terminator  1984          R  26 Oct 1984  107 min
# 247                Tangerines  2013  Not Rated  17 Apr 2015   87 min
# 249                   Aladdin  1992          G  25 Nov 1992   90 min
#
#                                                  Genre  \
# 0                                                Drama
# 1                                         Crime, Drama
# 2                                         Crime, Drama
# 3                       Action, Crime, Drama, Thriller
# 4                                         Crime, Drama
# ..                                                 ...
# 243                                              Drama
# 244                                    Comedy, Romance
# 246                                     Action, Sci-Fi
# 247                                         Drama, War
# 249  Animation, Adventure, Comedy, Family, Fantasy,...
#
#                       Director  \
# 0               Frank Darabont
# 1         Francis Ford Coppola
# 2         Francis Ford Coppola
# 3            Christopher Nolan
# 4                 Sidney Lumet
# ..                         ...
# 243                Tate Taylor
# 244            Charles Chaplin
# 246              James Cameron
# 247             Zaza Urushadze
# 249  Ron Clements, John Musker
#
#                                                 Writer  \
# 0    Stephen King (short story "Rita Hayworth and S...
# 1    Mario Puzo (screenplay by), Francis Ford Coppo...
# 2    Francis Ford Coppola (screenplay by), Mario Pu...
# 3    Jonathan Nolan (screenplay), Christopher Nolan...
# 4    Reginald Rose (story), Reginald Rose (screenplay)
# ..                                                 ...
# 243  Tate Taylor (screenplay), Kathryn Stockett (no...
# 244                                    Charles Chaplin
# 246  James Cameron, Gale Anne Hurd, William Wisher ...
# 247  Tatjana Mülbeier (idea), Zaza Urushadze (idea)...
# 249  Ron Clements (screenplay by), John Musker (scr...
#
#                                                 Actors  \
# 0    Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1    Marlon Brando, Al Pacino, James Caan, Richard ...
# 2    Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3    Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4    Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# ..                                                 ...
# 243  Emma Stone, Viola Davis, Bryce Dallas Howard, ...
# 244  Al Ernest Garcia, Merna Kennedy, Harry Crocker...
# 246  Arnold Schwarzenegger, Michael Biehn, Linda Ha...
# 247  Lembit Ulfsak, Giorgi Nakashidze, Misha Meskhi...
# 249  Scott Weinger, Robin Williams, Linda Larkin, J...
#
#                                                   Plot  ...  \
# 0    Two imprisoned men bond over a number of years...  ...
# 1    The aging patriarch of an organized crime dyna...  ...
# 2    The early life and career of Vito Corleone in ...  ...
# 3    When the menace known as the Joker wreaks havo...  ...
# 4    A jury holdout attempts to prevent a miscarria...  ...
# ..                                                 ...  ...
# 243  An aspiring author during the civil rights mov...  ...
# 244  The Tramp finds work and the girl of his dream...  ...
# 246  A human soldier is sent from 2029 to 1984 to s...  ...
# 247  In 1992, war rages in Abkhazia, a breakaway re...  ...
# 249  A kindhearted street urchin and a power-hungry...  ...
#
#                                                 Poster Metascore     imdbID  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...        80  tt0111161
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...       100  tt0068646
# 2    https://m.media-amazon.com/images/M/MV5BMWMwMG...        90  tt0071562
# 3    https://m.media-amazon.com/images/M/MV5BMTMxNT...        84  tt0468569
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...        96  tt0050083
# ..                                                 ...       ...        ...
# 243  https://m.media-amazon.com/images/M/MV5BMTM5OT...        62  tt1454029
# 244  https://m.media-amazon.com/images/M/MV5BM2QwYW...        90  tt0018773
# 246  https://m.media-amazon.com/images/M/MV5BYTViNz...        84  tt0088247
# 247  https://m.media-amazon.com/images/M/MV5BMTgwNz...        73  tt2991224
# 249  https://m.media-amazon.com/images/M/MV5BY2Q2ND...        86  tt0103639
#
#     imdbRating  imdbVotes   Type  DVD BoxOffice  \
# 0          9.3  2,296,430  movie  N/A       N/A
# 1          9.2  1,589,401  movie  N/A       N/A
# 2          9.0  1,110,514  movie  N/A       N/A
# 3          9.0  2,258,183  movie  N/A       N/A
# 4          8.9    674,457  movie  N/A       N/A
# ..         ...        ...    ...  ...       ...
# 243        8.0    423,006  movie  N/A       N/A
# 244        8.1     28,271  movie  N/A       N/A
# 246        8.0    791,452  movie  N/A       N/A
# 247        8.2     37,699  movie  N/A       N/A
# 249        8.0    365,666  movie  N/A       N/A
#
#                                        Production Website
# 0    Columbia Pictures, Castle Rock Entertainment     N/A
# 1                              Paramount Pictures     N/A
# 2             Paramount Pictures, Coppola Company     N/A
# 3                                         Syncopy     N/A
# 4                             Orion-Nova Pictures     N/A
# ..                                            ...     ...
# 243             1492 Pictures, Harbinger Pictures     N/A
# 244                   Charles Chaplin Productions     N/A
# 246                               Pacific Western     N/A
# 247                        Allfilm, Georgian-Film     N/A
# 249                          Walt Disney Pictures     N/A
#
# [241 rows x 22 columns]

# %%
#Export to csv
top_250_df.to_csv("Top_250_Movies.csv", index=False, header=True)
