# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import requests as req
from config import api_key
from pprint import pprint
import requests
import json
from datetime import datetime

# %%
# Create list of top 250 IMBD movies to loop through 
table_MN = pd.read_html('https://www.imdb.com/chart/top/?ref_=nv_mv_250')
top_250=table_MN[0]["Rank & Title"].str[4:-6]
top_250=list(top_250)

# %%
# Create base
base_url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key

# Set up lists to hold response data
Title=[]
Year=[]
Rated=[]
Released=[]
Runtime=[]
Genre=[]
Director=[]
Writer=[]
Actors=[]
Plot=[]
Language=[]
Country=[]
Poster=[]
Metascore=[]
imdbID=[]
imdbRating=[]
imdbVotes=[]
Type=[]
Production=[]

# %%
# Loop through movies and add info to lists 
for movie in top_250:
    target_url = base_url + movie + api_key
    response = requests.get(target_url).json()
    
    Title.append(response.get('Title'))
    Year.append(response.get('Year'))
    Rated.append(response.get('Rated'))
    Released.append(response.get('Released'))
    Runtime.append(response.get('Runtime'))
    Genre.append(response.get('Genre'))
    Director.append(response.get('Director'))
    Writer.append(response.get('Writer'))
    Actors.append(response.get('Actors'))
    Plot.append(response.get('Plot'))
    Language.append(response.get('Language'))
    Country.append(response.get('Country'))
    Poster.append(response.get('Poster'))
    Metascore.append(response.get('Metascore'))
    imdbID.append(response.get('imdbID'))
    imdbRating.append(response.get('imdbRating'))
    imdbVotes.append(response.get('imdbVotes'))
    Type.append(response.get('Type'))
    Production.append(response.get('Production'))

# %%
# Create dataframe to hold data
top_250_df = pd.DataFrame({
    "Title":Title,
    "Year":Year,
    "Rated":Rated,
    "Released":Released,
    "Runtime":Runtime,
    "Director":Director,
    "Plot":Plot,
    "Poster":Poster,
    "Metascore":Metascore,
    "imdbID":imdbID,
    "imdbRating":imdbRating,
    "imdbVotes":imdbVotes,
    "Type":Type
})

# %%
# Check for null value rows
top_250_df[top_250_df.isnull().any(axis=1)]

top_250_df.replace("N/A", None, inplace = True)

# Drop rows
top_250_df.dropna(how='all', inplace = True)

# %%
# Adding a rank column by resetting the index
top_250_df.reset_index(inplace = True)
top_250_df
# Out:
#      index                                           Title  Year      Rated  \
# 0        0                        The Shawshank Redemption  1994          R
# 1        1                                   The Godfather  1972          R
# 2        2                          The Godfather: Part II  1974          R
# 3        3                                 The Dark Knight  2008      PG-13
# 4        4                                    12 Angry Men  1957   Approved
# ..     ...                                             ...   ...        ...
# 237    244                                      The Circus  1928     Passed
# 238    246                                  The Terminator  1984          R
# 239    247                                      Tangerines  2013  Not Rated
# 240    248                                         Aladdin  1992          G
# 241    249  Neon Genesis Evangelion: The End of Evangelion  1997      TV-14
#
#         Released  Runtime                        Director  \
# 0    14 Oct 1994  142 min                  Frank Darabont
# 1    24 Mar 1972  175 min            Francis Ford Coppola
# 2    18 Dec 1974  202 min            Francis Ford Coppola
# 3    18 Jul 2008  152 min               Christopher Nolan
# 4    10 Apr 1957   96 min                    Sidney Lumet
# ..           ...      ...                             ...
# 237  29 Jan 1928   72 min                 Charles Chaplin
# 238  26 Oct 1984  107 min                   James Cameron
# 239  17 Apr 2015   87 min                  Zaza Urushadze
# 240  25 Nov 1992   90 min       Ron Clements, John Musker
# 241  01 Jun 2002   87 min  Hideaki Anno, Kazuya Tsurumaki
#
#                                                   Plot  \
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    The early life and career of Vito Corleone in ...
# 3    When the menace known as the Joker wreaks havo...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 237  The Tramp finds work and the girl of his dream...
# 238  A human soldier is sent from 2029 to 1984 to s...
# 239  In 1992, war rages in Abkhazia, a breakaway re...
# 240  A kindhearted street urchin and a power-hungry...
# 241  Concurrent theatrical ending of the TV series ...
#
#                                                 Poster Metascore     imdbID  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...        80  tt0111161
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...       100  tt0068646
# 2    https://m.media-amazon.com/images/M/MV5BMWMwMG...        90  tt0071562
# 3    https://m.media-amazon.com/images/M/MV5BMTMxNT...        84  tt0468569
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...        96  tt0050083
# ..                                                 ...       ...        ...
# 237  https://m.media-amazon.com/images/M/MV5BM2QwYW...        90  tt0018773
# 238  https://m.media-amazon.com/images/M/MV5BYTViNz...        84  tt0088247
# 239  https://m.media-amazon.com/images/M/MV5BMTgwNz...        73  tt2991224
# 240  https://m.media-amazon.com/images/M/MV5BY2Q2ND...        86  tt0103639
# 241  https://m.media-amazon.com/images/M/MV5BZjJhMT...        86  tt0169858
#
#     imdbRating  imdbVotes   Type
# 0          9.3  2,296,430  movie
# 1          9.2  1,589,401  movie
# 2          9.0  1,110,514  movie
# 3          9.0  2,268,809  movie
# 4          8.9    674,457  movie
# ..         ...        ...    ...
# 237        8.1     28,271  movie
# 238        8.0    791,452  movie
# 239        8.2     38,660  movie
# 240        8.0    369,423  movie
# 241        8.1     36,874  movie
#
# [242 rows x 14 columns]

# %%
# Increasing the value of the rank column by 1
top_250_df.rename(columns = {"index": "Rank"}, inplace = True)
top_250_df["Rank"] = top_250_df["Rank"].apply(lambda x: x + 1)
top_250_df
# Out:
#      Rank                                           Title  Year      Rated  \
# 0       1                        The Shawshank Redemption  1994          R
# 1       2                                   The Godfather  1972          R
# 2       3                          The Godfather: Part II  1974          R
# 3       4                                 The Dark Knight  2008      PG-13
# 4       5                                    12 Angry Men  1957   Approved
# ..    ...                                             ...   ...        ...
# 237   245                                      The Circus  1928     Passed
# 238   247                                  The Terminator  1984          R
# 239   248                                      Tangerines  2013  Not Rated
# 240   249                                         Aladdin  1992          G
# 241   250  Neon Genesis Evangelion: The End of Evangelion  1997      TV-14
#
#         Released  Runtime                        Director  \
# 0    14 Oct 1994  142 min                  Frank Darabont
# 1    24 Mar 1972  175 min            Francis Ford Coppola
# 2    18 Dec 1974  202 min            Francis Ford Coppola
# 3    18 Jul 2008  152 min               Christopher Nolan
# 4    10 Apr 1957   96 min                    Sidney Lumet
# ..           ...      ...                             ...
# 237  29 Jan 1928   72 min                 Charles Chaplin
# 238  26 Oct 1984  107 min                   James Cameron
# 239  17 Apr 2015   87 min                  Zaza Urushadze
# 240  25 Nov 1992   90 min       Ron Clements, John Musker
# 241  01 Jun 2002   87 min  Hideaki Anno, Kazuya Tsurumaki
#
#                                                   Plot  \
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    The early life and career of Vito Corleone in ...
# 3    When the menace known as the Joker wreaks havo...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 237  The Tramp finds work and the girl of his dream...
# 238  A human soldier is sent from 2029 to 1984 to s...
# 239  In 1992, war rages in Abkhazia, a breakaway re...
# 240  A kindhearted street urchin and a power-hungry...
# 241  Concurrent theatrical ending of the TV series ...
#
#                                                 Poster Metascore     imdbID  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...        80  tt0111161
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...       100  tt0068646
# 2    https://m.media-amazon.com/images/M/MV5BMWMwMG...        90  tt0071562
# 3    https://m.media-amazon.com/images/M/MV5BMTMxNT...        84  tt0468569
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...        96  tt0050083
# ..                                                 ...       ...        ...
# 237  https://m.media-amazon.com/images/M/MV5BM2QwYW...        90  tt0018773
# 238  https://m.media-amazon.com/images/M/MV5BYTViNz...        84  tt0088247
# 239  https://m.media-amazon.com/images/M/MV5BMTgwNz...        73  tt2991224
# 240  https://m.media-amazon.com/images/M/MV5BY2Q2ND...        86  tt0103639
# 241  https://m.media-amazon.com/images/M/MV5BZjJhMT...        86  tt0169858
#
#     imdbRating  imdbVotes   Type
# 0          9.3  2,296,430  movie
# 1          9.2  1,589,401  movie
# 2          9.0  1,110,514  movie
# 3          9.0  2,268,809  movie
# 4          8.9    674,457  movie
# ..         ...        ...    ...
# 237        8.1     28,271  movie
# 238        8.0    791,452  movie
# 239        8.2     38,660  movie
# 240        8.0    369,423  movie
# 241        8.1     36,874  movie
#
# [242 rows x 14 columns]

# %%
# Removing the "min" from the Runtime string
top_250_df["Runtime"] = top_250_df["Runtime"].str[:-3]
top_250_df
# Out:
#      Rank                                           Title  Year      Rated  \
# 0       1                        The Shawshank Redemption  1994          R
# 1       2                                   The Godfather  1972          R
# 2       3                          The Godfather: Part II  1974          R
# 3       4                                 The Dark Knight  2008      PG-13
# 4       5                                    12 Angry Men  1957   Approved
# ..    ...                                             ...   ...        ...
# 237   245                                      The Circus  1928     Passed
# 238   247                                  The Terminator  1984          R
# 239   248                                      Tangerines  2013  Not Rated
# 240   249                                         Aladdin  1992          G
# 241   250  Neon Genesis Evangelion: The End of Evangelion  1997      TV-14
#
#         Released Runtime                        Director  \
# 0    14 Oct 1994    142                   Frank Darabont
# 1    24 Mar 1972    175             Francis Ford Coppola
# 2    18 Dec 1974    202             Francis Ford Coppola
# 3    18 Jul 2008    152                Christopher Nolan
# 4    10 Apr 1957     96                     Sidney Lumet
# ..           ...     ...                             ...
# 237  29 Jan 1928     72                  Charles Chaplin
# 238  26 Oct 1984    107                    James Cameron
# 239  17 Apr 2015     87                   Zaza Urushadze
# 240  25 Nov 1992     90        Ron Clements, John Musker
# 241  01 Jun 2002     87   Hideaki Anno, Kazuya Tsurumaki
#
#                                                   Plot  \
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    The early life and career of Vito Corleone in ...
# 3    When the menace known as the Joker wreaks havo...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 237  The Tramp finds work and the girl of his dream...
# 238  A human soldier is sent from 2029 to 1984 to s...
# 239  In 1992, war rages in Abkhazia, a breakaway re...
# 240  A kindhearted street urchin and a power-hungry...
# 241  Concurrent theatrical ending of the TV series ...
#
#                                                 Poster Metascore     imdbID  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...        80  tt0111161
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...       100  tt0068646
# 2    https://m.media-amazon.com/images/M/MV5BMWMwMG...        90  tt0071562
# 3    https://m.media-amazon.com/images/M/MV5BMTMxNT...        84  tt0468569
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...        96  tt0050083
# ..                                                 ...       ...        ...
# 237  https://m.media-amazon.com/images/M/MV5BM2QwYW...        90  tt0018773
# 238  https://m.media-amazon.com/images/M/MV5BYTViNz...        84  tt0088247
# 239  https://m.media-amazon.com/images/M/MV5BMTgwNz...        73  tt2991224
# 240  https://m.media-amazon.com/images/M/MV5BY2Q2ND...        86  tt0103639
# 241  https://m.media-amazon.com/images/M/MV5BZjJhMT...        86  tt0169858
#
#     imdbRating  imdbVotes   Type
# 0          9.3  2,296,430  movie
# 1          9.2  1,589,401  movie
# 2          9.0  1,110,514  movie
# 3          9.0  2,268,809  movie
# 4          8.9    674,457  movie
# ..         ...        ...    ...
# 237        8.1     28,271  movie
# 238        8.0    791,452  movie
# 239        8.2     38,660  movie
# 240        8.0    369,423  movie
# 241        8.1     36,874  movie
#
# [242 rows x 14 columns]

# %%
# Formatting the date to be read by SQL
top_250_df["Released"] = top_250_df["Released"].apply(lambda x: datetime.strptime(x, "%d %b %Y").strftime("%Y-%m-%d"))
top_250_df
# Out:
#      Rank                                           Title  Year      Rated  \
# 0       1                        The Shawshank Redemption  1994          R
# 1       2                                   The Godfather  1972          R
# 2       3                          The Godfather: Part II  1974          R
# 3       4                                 The Dark Knight  2008      PG-13
# 4       5                                    12 Angry Men  1957   Approved
# ..    ...                                             ...   ...        ...
# 237   245                                      The Circus  1928     Passed
# 238   247                                  The Terminator  1984          R
# 239   248                                      Tangerines  2013  Not Rated
# 240   249                                         Aladdin  1992          G
# 241   250  Neon Genesis Evangelion: The End of Evangelion  1997      TV-14
#
#        Released Runtime                        Director  \
# 0    1994-10-14    142                   Frank Darabont
# 1    1972-03-24    175             Francis Ford Coppola
# 2    1974-12-18    202             Francis Ford Coppola
# 3    2008-07-18    152                Christopher Nolan
# 4    1957-04-10     96                     Sidney Lumet
# ..          ...     ...                             ...
# 237  1928-01-29     72                  Charles Chaplin
# 238  1984-10-26    107                    James Cameron
# 239  2015-04-17     87                   Zaza Urushadze
# 240  1992-11-25     90        Ron Clements, John Musker
# 241  2002-06-01     87   Hideaki Anno, Kazuya Tsurumaki
#
#                                                   Plot  \
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    The early life and career of Vito Corleone in ...
# 3    When the menace known as the Joker wreaks havo...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 237  The Tramp finds work and the girl of his dream...
# 238  A human soldier is sent from 2029 to 1984 to s...
# 239  In 1992, war rages in Abkhazia, a breakaway re...
# 240  A kindhearted street urchin and a power-hungry...
# 241  Concurrent theatrical ending of the TV series ...
#
#                                                 Poster Metascore     imdbID  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...        80  tt0111161
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...       100  tt0068646
# 2    https://m.media-amazon.com/images/M/MV5BMWMwMG...        90  tt0071562
# 3    https://m.media-amazon.com/images/M/MV5BMTMxNT...        84  tt0468569
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...        96  tt0050083
# ..                                                 ...       ...        ...
# 237  https://m.media-amazon.com/images/M/MV5BM2QwYW...        90  tt0018773
# 238  https://m.media-amazon.com/images/M/MV5BYTViNz...        84  tt0088247
# 239  https://m.media-amazon.com/images/M/MV5BMTgwNz...        73  tt2991224
# 240  https://m.media-amazon.com/images/M/MV5BY2Q2ND...        86  tt0103639
# 241  https://m.media-amazon.com/images/M/MV5BZjJhMT...        86  tt0169858
#
#     imdbRating  imdbVotes   Type
# 0          9.3  2,296,430  movie
# 1          9.2  1,589,401  movie
# 2          9.0  1,110,514  movie
# 3          9.0  2,268,809  movie
# 4          8.9    674,457  movie
# ..         ...        ...    ...
# 237        8.1     28,271  movie
# 238        8.0    791,452  movie
# 239        8.2     38,660  movie
# 240        8.0    369,423  movie
# 241        8.1     36,874  movie
#
# [242 rows x 14 columns]

# %%
# Export to csv
top_250_df.to_csv("Top_250_Movies.csv", index=False, header=True)

# %%
# Creating a new dataframe to store the title and genre
top_250_genre_df = pd.DataFrame({
    "imdbID": imdbID, 
    "Title": Title,
    "Genre": Genre
})

top_250_genre_df
# Out:
#         imdbID                                           Title  \
# 0    tt0111161                        The Shawshank Redemption
# 1    tt0068646                                   The Godfather
# 2    tt0071562                          The Godfather: Part II
# 3    tt0468569                                 The Dark Knight
# 4    tt0050083                                    12 Angry Men
# ..         ...                                             ...
# 245       None                                            None
# 246  tt0088247                                  The Terminator
# 247  tt2991224                                      Tangerines
# 248  tt0103639                                         Aladdin
# 249  tt0169858  Neon Genesis Evangelion: The End of Evangelion
#
#                                                  Genre
# 0                                                Drama
# 1                                         Crime, Drama
# 2                                         Crime, Drama
# 3                       Action, Crime, Drama, Thriller
# 4                                         Crime, Drama
# ..                                                 ...
# 245                                               None
# 246                                     Action, Sci-Fi
# 247                                         Drama, War
# 248  Animation, Adventure, Comedy, Family, Fantasy,...
# 249          Animation, Action, Drama, Fantasy, Sci-Fi
#
# [250 rows x 3 columns]

# %%
# Checking for null values
top_250_genre_df.isnull().sum()
# Out:
# imdbID    8
# Title     8
# Genre     8
# dtype: int64

# %%
# Dropping any null values and resetting the index
top_250_genre_df.replace("N/A", None, inplace = True)

top_250_genre_df.dropna(how = "any", inplace = True)

top_250_genre_df.reset_index(drop = True, inplace = True)

# %%
# Creating empty lists to hold information for new dataframe
id_list = []
title_list = []
genre_list = []

# Looping through the dataframe to seperate data into first normal form
for i in range(0, len(top_250_genre_df)):
    if len(top_250_genre_df["Genre"][i].split(",")) > 1:
        words = top_250_genre_df["Genre"][i].split(",")
        result = list(map(lambda x: x.strip(), words))
        
        genre_list.extend(result)
        
        for j in range(0, len(top_250_genre_df["Genre"][i].split(","))):
            id_list.append(top_250_genre_df["imdbID"][i])
            title_list.append(top_250_genre_df["Title"][i])
    else:
        words = top_250_genre_df["Genre"][i].strip()
        
        genre_list.append(words)
        
        id_list.append(top_250_genre_df["imdbID"][i])
        title_list.append(top_250_genre_df["Title"][i])

# %%
# Creating the new genre dataframe in first normal form
genre_df = pd.DataFrame({
    "imdbID": id_list,
    "Title": title_list,
    "Genre": genre_list
})

genre_df
# Out:
#         imdbID                                           Title      Genre
# 0    tt0111161                        The Shawshank Redemption      Drama
# 1    tt0068646                                   The Godfather      Crime
# 2    tt0068646                                   The Godfather      Drama
# 3    tt0071562                          The Godfather: Part II      Crime
# 4    tt0071562                          The Godfather: Part II      Drama
# ..         ...                                             ...        ...
# 690  tt0169858  Neon Genesis Evangelion: The End of Evangelion  Animation
# 691  tt0169858  Neon Genesis Evangelion: The End of Evangelion     Action
# 692  tt0169858  Neon Genesis Evangelion: The End of Evangelion      Drama
# 693  tt0169858  Neon Genesis Evangelion: The End of Evangelion    Fantasy
# 694  tt0169858  Neon Genesis Evangelion: The End of Evangelion     Sci-Fi
#
# [695 rows x 3 columns]

# %%
# Exporting as a CSV
genre_df.to_csv("top_250_genres.csv", index=False, header=True)
