# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import requests as req
from config import api_key
from pprint import pprint
import requests
import json

# %%
#Create list of top 250 IMBD movies to loop through 
table_MN = pd.read_html('https://www.imdb.com/chart/moviemeter/')
pop_100_list=table_MN[0]["Rank & Title"]
pop_100_list=list(pop_100_list.apply(lambda x: x.split("(")[0]))

# %%
#Create base
base_url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key

#Set up lists to hold response data
Title=[]
Year=[]
Rated=[]
Released=[]
Runtime=[]
Genre=[]
Director=[]
Writer=[]
Actors=[]
Plot=[]
Language=[]
Country=[]
Poster=[]
Metascore=[]
imdbID=[]
imdbRating=[]
imdbVotes=[]
Type=[]
DVD=[]
BoxOffice=[]
Production=[]
Website=[]

# %%
#Loop through movies and add info to lists 
for movie in pop_100_list:
    target_url = base_url + movie + api_key
    response = requests.get(target_url).json()
    
    Title.append(response.get('Title'))
    Year.append(response.get('Year'))
    Rated.append(response.get('Rated'))
    Released.append(response.get('Released'))
    Runtime.append(response.get('Runtime'))
    Genre.append(response.get('Genre'))
    Director.append(response.get('Director'))
    Writer.append(response.get('Writer'))
    Actors.append(response.get('Actors'))
    Plot.append(response.get('Plot'))
    Language.append(response.get('Language'))
    Country.append(response.get('Country'))
    Poster.append(response.get('Poster'))
    Metascore.append(response.get('Metascore'))
    imdbID.append(response.get('imdbID'))
    imdbRating.append(response.get('imdbRating'))
    imdbVotes.append(response.get('imdbVotes'))
    Type.append(response.get('Type'))
    DVD.append(response.get('DVD'))
    BoxOffice.append(response.get('BoxOffice'))
    Production.append(response.get('Production'))
    Website.append(response.get('Website'))

# %%
pop_100_df = pd.DataFrame({
    "Title":Title,
    "Year":Year,
    "Rated":Rated,
    "Released":Released,
    "Runtime":Runtime,
    "Genre":Genre,
    "Director":Director,
    "Writer":Writer,
    "Actors":Actors,
    "Plot":Plot,
    "Language":Language,
    "Country":Country,
    "Poster":Poster,
    "Metascore":Metascore,
    "imdbID":imdbID,
    "imdbRating":imdbRating,
    "imdbVotes":imdbVotes,
    "Type":Type,
    "DVD":DVD,
    "BoxOffice":BoxOffice,
    "Production":Production,
    "Website":Website
})
# Out:
#                          Title  Year  Rated     Released  Runtime  \
# 0                     Holidate  2020  TV-MA  28 Oct 2020  103 min
# 1   Borat Subsequent Moviefilm  2020      R  23 Oct 2020   95 min
# 2                  Hocus Pocus  1993     PG  16 Jul 1993   96 min
# 3                  The Witches  1990     PG  24 Aug 1990   91 min
# 4                    His House  2020  TV-14  30 Oct 2020   93 min
# ..                         ...   ...    ...          ...      ...
# 95                     Get Out  2017      R  24 Feb 2017  104 min
# 96                        Dune  1984  PG-13  14 Dec 1984  137 min
# 97           The Suicide Squad  2021    N/A  06 Aug 2021      N/A
# 98    The Shawshank Redemption  1994      R  14 Oct 1994  142 min
# 99   A Nightmare on Elm Street  1984  TV-14  16 Nov 1984   91 min
#
#                                                 Genre        Director  \
# 0                                     Comedy, Romance  John Whitesell
# 1                                   Adventure, Comedy   Jason Woliner
# 2                             Comedy, Family, Fantasy    Kenny Ortega
# 3   Adventure, Comedy, Family, Fantasy, Horror, My...    Nicolas Roeg
# 4                             Drama, Horror, Thriller     Remi Weekes
# ..                                                ...             ...
# 95                          Horror, Mystery, Thriller    Jordan Peele
# 96                          Action, Adventure, Sci-Fi     David Lynch
# 97        Action, Adventure, Fantasy, Mystery, Sci-Fi      James Gunn
# 98                                              Drama  Frank Darabont
# 99                                             Horror      Wes Craven
#
#                                                Writer  \
# 0                                     Tiffany Paulsen
# 1   Sacha Baron Cohen (screenplay by), Anthony Hin...
# 2   David Kirschner (story), Mick Garris (story), ...
# 3         Roald Dahl (book), Allan Scott (screenplay)
# 4   Felicity Evans (Story by), Toby Venables (Stor...
# ..                                                ...
# 95                                       Jordan Peele
# 96    Frank Herbert (novel), David Lynch (screenplay)
# 97            James Gunn, John Ostrander (comic book)
# 98  Stephen King (short story "Rita Hayworth and S...
# 99                                         Wes Craven
#
#                                                Actors  \
# 0   Emma Roberts, Luke Bracey, Kristin Chenoweth, ...
# 1   Sacha Baron Cohen, Maria Bakalova, Tom Hanks, ...
# 2   Bette Midler, Sarah Jessica Parker, Kathy Naji...
# 3   Anjelica Huston, Mai Zetterling, Jasen Fisher,...
# 4   Sope Dirisu, Wunmi Mosaku, Malaika Wakoli-Abig...
# ..                                                ...
# 95  Daniel Kaluuya, Allison Williams, Catherine Ke...
# 96  Francesca Annis, Leonardo Cimino, Brad Dourif,...
# 97  Margot Robbie, Idris Elba, Taika Waititi, Joel...
# 98  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 99  John Saxon, Ronee Blakley, Heather Langenkamp,...
#
#                                                  Plot  ...  \
# 0   Fed up with being single on holidays, two stra...  ...
# 1   Follow-up film to the 2006 comedy centering on...  ...
# 2   A curious youngster moves to Salem, where he s...  ...
# 3   A young boy stumbles onto a witch convention a...  ...
# 4   A refugee couple makes a harrowing escape from...  ...
# ..                                                ...  ...
# 95  A young African-American visits his white girl...  ...
# 96  A Duke's son leads desert warriors against the...  ...
# 97                                   Plot is unknown.  ...
# 98  Two imprisoned men bond over a number of years...  ...
# 99  The monstrous spirit of a slain child murderer...  ...
#
#                                                Poster Metascore      imdbID  \
# 0   https://m.media-amazon.com/images/M/MV5BYWVmYT...        44   tt9866072
# 1   https://m.media-amazon.com/images/M/MV5BZmY2Zm...        68  tt13143964
# 2   https://m.media-amazon.com/images/M/MV5BMWUxNW...       N/A   tt0107120
# 3   https://m.media-amazon.com/images/M/MV5BMjI1MD...        78   tt0100944
# 4   https://m.media-amazon.com/images/M/MV5BODY2Nj...        72   tt8508734
# ..                                                ...       ...         ...
# 95  https://m.media-amazon.com/images/M/MV5BMjUxMD...        85   tt5052448
# 96  https://m.media-amazon.com/images/M/MV5BYTAzYz...        40   tt0087182
# 97  https://m.media-amazon.com/images/M/MV5BMzEzNz...       N/A   tt6334354
# 98  https://m.media-amazon.com/images/M/MV5BMDFkYT...        80   tt0111161
# 99  https://m.media-amazon.com/images/M/MV5BNzFjZm...        76   tt0087800
#
#    imdbRating  imdbVotes   Type  DVD BoxOffice  \
# 0         6.1     12,141  movie  N/A       N/A
# 1         6.8     75,370  movie  N/A       N/A
# 2         6.9    101,320  movie  N/A       N/A
# 3         6.8     38,250  movie  N/A       N/A
# 4         6.3      2,623  movie  N/A       N/A
# ..        ...        ...    ...  ...       ...
# 95        7.7    477,064  movie  N/A       N/A
# 96        6.5    124,531  movie  N/A       N/A
# 97        N/A        N/A  movie  N/A       N/A
# 98        9.3  2,296,430  movie  N/A       N/A
# 99        7.5    201,589  movie  N/A       N/A
#
#                                            Production Website
# 0                                                 N/A     N/A
# 1                                                 N/A     N/A
# 2                                Walt Disney Pictures     N/A
# 3   Jim Henson Productions, Lorimar Film Entertain...     N/A
# 4                                                 N/A     N/A
# ..                                                ...     ...
# 95  Universal Pictures, QC Entertainment, Blumhous...     N/A
# 96       Universal Pictures, DeLaurentiis Productions     N/A
# 97                                                N/A     N/A
# 98       Columbia Pictures, Castle Rock Entertainment     N/A
# 99                                    New Line Cinema     N/A
#
# [100 rows x 22 columns]

# %%
#Check for null value rows
pop_100_df[pop_100_df.isnull().any(axis=1)]

#Drop rows
pop_100_df.dropna(how='all')
# Out:
#                          Title  Year  Rated     Released  Runtime  \
# 0                     Holidate  2020  TV-MA  28 Oct 2020  103 min
# 1   Borat Subsequent Moviefilm  2020      R  23 Oct 2020   95 min
# 2                  Hocus Pocus  1993     PG  16 Jul 1993   96 min
# 3                  The Witches  1990     PG  24 Aug 1990   91 min
# 4                    His House  2020  TV-14  30 Oct 2020   93 min
# ..                         ...   ...    ...          ...      ...
# 95                     Get Out  2017      R  24 Feb 2017  104 min
# 96                        Dune  1984  PG-13  14 Dec 1984  137 min
# 97           The Suicide Squad  2021    N/A  06 Aug 2021      N/A
# 98    The Shawshank Redemption  1994      R  14 Oct 1994  142 min
# 99   A Nightmare on Elm Street  1984  TV-14  16 Nov 1984   91 min
#
#                                                 Genre        Director  \
# 0                                     Comedy, Romance  John Whitesell
# 1                                   Adventure, Comedy   Jason Woliner
# 2                             Comedy, Family, Fantasy    Kenny Ortega
# 3   Adventure, Comedy, Family, Fantasy, Horror, My...    Nicolas Roeg
# 4                             Drama, Horror, Thriller     Remi Weekes
# ..                                                ...             ...
# 95                          Horror, Mystery, Thriller    Jordan Peele
# 96                          Action, Adventure, Sci-Fi     David Lynch
# 97        Action, Adventure, Fantasy, Mystery, Sci-Fi      James Gunn
# 98                                              Drama  Frank Darabont
# 99                                             Horror      Wes Craven
#
#                                                Writer  \
# 0                                     Tiffany Paulsen
# 1   Sacha Baron Cohen (screenplay by), Anthony Hin...
# 2   David Kirschner (story), Mick Garris (story), ...
# 3         Roald Dahl (book), Allan Scott (screenplay)
# 4   Felicity Evans (Story by), Toby Venables (Stor...
# ..                                                ...
# 95                                       Jordan Peele
# 96    Frank Herbert (novel), David Lynch (screenplay)
# 97            James Gunn, John Ostrander (comic book)
# 98  Stephen King (short story "Rita Hayworth and S...
# 99                                         Wes Craven
#
#                                                Actors  \
# 0   Emma Roberts, Luke Bracey, Kristin Chenoweth, ...
# 1   Sacha Baron Cohen, Maria Bakalova, Tom Hanks, ...
# 2   Bette Midler, Sarah Jessica Parker, Kathy Naji...
# 3   Anjelica Huston, Mai Zetterling, Jasen Fisher,...
# 4   Sope Dirisu, Wunmi Mosaku, Malaika Wakoli-Abig...
# ..                                                ...
# 95  Daniel Kaluuya, Allison Williams, Catherine Ke...
# 96  Francesca Annis, Leonardo Cimino, Brad Dourif,...
# 97  Margot Robbie, Idris Elba, Taika Waititi, Joel...
# 98  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 99  John Saxon, Ronee Blakley, Heather Langenkamp,...
#
#                                                  Plot  ...  \
# 0   Fed up with being single on holidays, two stra...  ...
# 1   Follow-up film to the 2006 comedy centering on...  ...
# 2   A curious youngster moves to Salem, where he s...  ...
# 3   A young boy stumbles onto a witch convention a...  ...
# 4   A refugee couple makes a harrowing escape from...  ...
# ..                                                ...  ...
# 95  A young African-American visits his white girl...  ...
# 96  A Duke's son leads desert warriors against the...  ...
# 97                                   Plot is unknown.  ...
# 98  Two imprisoned men bond over a number of years...  ...
# 99  The monstrous spirit of a slain child murderer...  ...
#
#                                                Poster Metascore      imdbID  \
# 0   https://m.media-amazon.com/images/M/MV5BYWVmYT...        44   tt9866072
# 1   https://m.media-amazon.com/images/M/MV5BZmY2Zm...        68  tt13143964
# 2   https://m.media-amazon.com/images/M/MV5BMWUxNW...       N/A   tt0107120
# 3   https://m.media-amazon.com/images/M/MV5BMjI1MD...        78   tt0100944
# 4   https://m.media-amazon.com/images/M/MV5BODY2Nj...        72   tt8508734
# ..                                                ...       ...         ...
# 95  https://m.media-amazon.com/images/M/MV5BMjUxMD...        85   tt5052448
# 96  https://m.media-amazon.com/images/M/MV5BYTAzYz...        40   tt0087182
# 97  https://m.media-amazon.com/images/M/MV5BMzEzNz...       N/A   tt6334354
# 98  https://m.media-amazon.com/images/M/MV5BMDFkYT...        80   tt0111161
# 99  https://m.media-amazon.com/images/M/MV5BNzFjZm...        76   tt0087800
#
#    imdbRating  imdbVotes   Type  DVD BoxOffice  \
# 0         6.1     12,141  movie  N/A       N/A
# 1         6.8     75,370  movie  N/A       N/A
# 2         6.9    101,320  movie  N/A       N/A
# 3         6.8     38,250  movie  N/A       N/A
# 4         6.3      2,623  movie  N/A       N/A
# ..        ...        ...    ...  ...       ...
# 95        7.7    477,064  movie  N/A       N/A
# 96        6.5    124,531  movie  N/A       N/A
# 97        N/A        N/A  movie  N/A       N/A
# 98        9.3  2,296,430  movie  N/A       N/A
# 99        7.5    201,589  movie  N/A       N/A
#
#                                            Production Website
# 0                                                 N/A     N/A
# 1                                                 N/A     N/A
# 2                                Walt Disney Pictures     N/A
# 3   Jim Henson Productions, Lorimar Film Entertain...     N/A
# 4                                                 N/A     N/A
# ..                                                ...     ...
# 95  Universal Pictures, QC Entertainment, Blumhous...     N/A
# 96       Universal Pictures, DeLaurentiis Productions     N/A
# 97                                                N/A     N/A
# 98       Columbia Pictures, Castle Rock Entertainment     N/A
# 99                                    New Line Cinema     N/A
#
# [97 rows x 22 columns]

# %%
#Export to csv
pop_100_df.to_csv("Top_100_Popular_Movies.csv", index=False, header=True)
